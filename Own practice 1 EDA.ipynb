# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib as mp

# %%
data = pd.read_excel('E:/Own Practice/ALCOHOL.xlsx')

# %%
data
# Out:
#      S No Brand Code                                         Brand Name  \
# 0       1      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 1       2      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 2       3      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 3       4       BIIS                  BECK'S ICE INTERNATIONAL STRENGTH
# 4       5       BIIS                  BECK'S ICE INTERNATIONAL STRENGTH
# ..    ...        ...                                                ...
# 140   141       WRLB                  WHITE RHINO BREWING CO.LAGER BEER
# 141   142        WRB  WHITE RHINO BREWING CO.WIT,BELGIAN STYLE WHEAT...
# 142   143         YB                                  YAVIRA LAGER BEER
# 143   144         YB                                  YAVIRA LAGER BEER
# 144   145         YB                                  YAVIRA LAGER BEER
#
#      Size Value (ml)  Pack Size  Retail Price (Rs)  \
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of      S No Brand Code                                         Brand Name  \
# 0       1      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 1       2      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 2       3      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 3       4       BIIS                  BECK'S ICE INTERNATIONAL STRENGTH
# 4       5       BIIS                  BECK'S ICE INTERNATIONAL STRENGTH
# ..    ...        ...                                                ...
# 140   141       WRLB                  WHITE RHINO BREWING CO.LAGER BEER
# 141   142        WRB  WHITE RHINO BREWING CO.WIT,BELGIAN STYLE WHEAT...
# 142   143         YB                                  YAVIRA LAGER BEER
# 143   144         YB                                  YAVIRA LAGER BEER
# 144   145         YB                                  YAVIRA LAGER BEER
#
#      Size Value (ml)  Pack Size  Retail Price (Rs)  \
# ...

# %%
data.head()
# Out:
#    S No Brand Code                         Brand Name  Size Value (ml)  \
# 0     1      BMSEB       BAD MONKEY SUPER STRONG BEER              330
# 1     2      BMSEB       BAD MONKEY SUPER STRONG BEER              500
# 2     3      BMSEB       BAD MONKEY SUPER STRONG BEER              650
# 3     4       BIIS  BECK'S ICE INTERNATIONAL STRENGTH              500
# 4     5       BIIS  BECK'S ICE INTERNATIONAL STRENGTH              650
#
#    Pack Size  Retail Price (Rs)                      Warehouse Name
# 0         24                 70  M/S SINQ BEVERAGES PRIVATE LIMITED
# 1         24                100  M/S SINQ BEVERAGES PRIVATE LIMITED
# 2         12                130  M/S SINQ BEVERAGES PRIVATE LIMITED
# 3         24                105  M/S ANHEUSER BUSCH INBEV INDIA LTD
# 4         12                140  M/S ANHEUSER BUSCH INBEV INDIA LTD

# %%
data.tail()
# Out:
#      S No Brand Code                                         Brand Name  \
# 140   141       WRLB                  WHITE RHINO BREWING CO.LAGER BEER
# 141   142        WRB  WHITE RHINO BREWING CO.WIT,BELGIAN STYLE WHEAT...
# 142   143         YB                                  YAVIRA LAGER BEER
# 143   144         YB                                  YAVIRA LAGER BEER
# 144   145         YB                                  YAVIRA LAGER BEER
#
#      Size Value (ml)  Pack Size  Retail Price (Rs)  \
# 140              330         24                160
# 141              330         24                160
# 142              500         24                130
# 143              500         24                130
# 144              650         12                170
#
#                          Warehouse Name
# 140         M/S. HIMALAYAN ALES PVT LTD
# 141         M/S. HIMALAYAN ALES PVT LTD
# 142  M/S KIMAYA HIMALAYAN BEVERAGES LLP
# 143  M/S KIMAYA HIMALAYAN BEVERAGES LLP
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of      S No Brand Code                                         Brand Name  \
# 0       1      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 1       2      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 2       3      BMSEB                       BAD MONKEY SUPER STRONG BEER
# 3       4       BIIS                  BECK'S ICE INTERNATIONAL STRENGTH
# 4       5       BIIS                  BECK'S ICE INTERNATIONAL STRENGTH
# ..    ...        ...                                                ...
# 140   141       WRLB                  WHITE RHINO BREWING CO.LAGER BEER
# 141   142        WRB  WHITE RHINO BREWING CO.WIT,BELGIAN STYLE WHEAT...
# 142   143         YB                                  YAVIRA LAGER BEER
# 143   144         YB                                  YAVIRA LAGER BEER
# 144   145         YB                                  YAVIRA LAGER BEER
#
#      Size Value (ml)  Pack Size  Retail Price (Rs)  \
# ...

# %%
data.describe()
# Out:
#              S No  Size Value (ml)   Pack Size  Retail Price (Rs)
# count  145.000000       145.000000  145.000000         145.000000
# mean    73.000000       586.793103   19.820690         169.931034
# std     42.001984       656.039695    6.123349         344.168677
# min      1.000000       325.000000    2.000000          55.000000
# 25%     37.000000       330.000000   12.000000         100.000000
# 50%     73.000000       500.000000   24.000000         120.000000
# 75%    109.000000       650.000000   24.000000         150.000000
# max    145.000000      5000.000000   24.000000        2550.000000

# %%
data.min()
# Out:
# S No                                                1
# Brand Code                                       B91B
# Brand Name               BAD MONKEY SUPER STRONG BEER
# Size Value (ml)                                   325
# Pack Size                                           2
# Retail Price (Rs)                                  55
# Warehouse Name       ADIE BROSWON BREWERIES PVT. LTD.
# dtype: object

# %%
data.isnull()
# Out:
#       S No  Brand Code  Brand Name  Size Value (ml)  Pack Size  \
# 0    False       False       False            False      False
# 1    False       False       False            False      False
# 2    False       False       False            False      False
# 3    False       False       False            False      False
# 4    False       False       False            False      False
# ..     ...         ...         ...              ...        ...
# 140  False       False       False            False      False
# 141  False       False       False            False      False
# 142  False       False       False            False      False
# 143  False       False       False            False      False
# 144  False       False       False            False      False
#
#      Retail Price (Rs)  Warehouse Name
# 0                False           False
# 1                False           False
# 2                False           False
# 3                False           False
# ...

# %%
data.isnull().sum()
# Out:
# S No                 0
# Brand Code           0
# Brand Name           0
# Size Value (ml)      0
# Pack Size            0
# Retail Price (Rs)    0
# Warehouse Name       0
# dtype: int64

# %%
data.nunique()
# Out:
# S No                 145
# Brand Code            54
# Brand Name            54
# Size Value (ml)        5
# Pack Size              3
# Retail Price (Rs)     29
# Warehouse Name        19
# dtype: int64

# %%
data.shape
# Out:
# (145, 7)

# %%
data.columns
# Out:
# Index(['S No', 'Brand Code', 'Brand Name', 'Size Value (ml)', 'Pack Size',
#        'Retail Price (Rs)', 'Warehouse Name'],
#       dtype='object')

# %%
data1 = pd.read_excel('E:/Own Practice/ALCOHOL.xlsx',sheet_name=1)

# %%
data1
# Out:
#      S No Brand Code                             Brand Name  Size Value (ml)  \
# 0       1       HPSW         100 PIPER BLEND.S. WHISKY 12YO               60
# 1       2       HPSW         100 PIPER BLEND.S. WHISKY 12YO              180
# 2       3       HPSW         100 PIPER BLEND.S. WHISKY 12YO              375
# 3       4       HPSW         100 PIPER BLEND.S. WHISKY 12YO              750
# 4       5       HPDB           100 PIPERS DL BLE SC. WHISKY               60
# ..    ...        ...                                    ...              ...
# 376   377       WHRW             WHITE HILLS RESERVE WHISKY              750
# 377   378       WHRW             WHITE HILLS RESERVE WHISKY             1000
# 378   379      WLBSW  WILLIAM LAWSONS BLENDED SCOTCH WHISKY              180
# 379   380      WLBSW  WILLIAM LAWSONS BLENDED SCOTCH WHISKY              375
# 380   381      WLBSW  WILLIAM LAWSONS BLENDED SCOTCH WHISKY              750
#
# ...

# %%
data2 = pd.read_excel('E:/Own Practice/ALCOHOL.xlsx',sheet_name=2)

# %%
data2
# Out:
#     S No Brand Code                                         Brand Name  \
# 0      1       B91B      BIRA 91 BLONDE SUMMER LAGER BEER DRAUGHT BEER
# 1      2       B91B      BIRA 91 BLONDE SUMMER LAGER BEER DRAUGHT BEER
# 2      3       B91I   BIRA 91 INDIAN PALE ALE POMELO BEER DRAUGHT BEER
# 3      4       B91I   BIRA 91 INDIAN PALE ALE POMELO BEER DRAUGHT BEER
# 4      5       B91M            BIRA 91 MALABAR STOUT BEER DRAUGHT BEER
# 5      6       B91M            BIRA 91 MALABAR STOUT BEER DRAUGHT BEER
# 6      7       KPLB           KINGFISHER PRMR. LAGER BEER DRAUGHT BEER
# 7      8       KPLB           KINGFISHER PRMR. LAGER BEER DRAUGHT BEER
# 8      9       KPLB           KINGFISHER PRMR. LAGER BEER DRAUGHT BEER
# 9     10       KBFP             KOTSBERG FINEST PILS BEER DRAUGHT BEER
# 10    11        OBL           ORIGINAL BIRA 91 LIGHT BEER DRAUGHT BEER
# 11    12        OBL           ORIGINAL BIRA 91 LIGHT BEER DRAUGHT BEER
# ...

# %%
data3 = pd.read_excel('E:/Own Practice/ALCOHOL.xlsx',sheet_name=3)

# %%
data3
# Out:
#      S No Brand Code                                         Brand Name  \
# 0       1       ARVO                                        ARTIC VODKA
# 1       2       ARVO                                        ARTIC VODKA
# 2       3       ARVO                                        ARTIC VODKA
# 3       4       AVNO                         ARTIC VODKA NATURAL ORANGE
# 4       5       AVNO                         ARTIC VODKA NATURAL ORANGE
# ..    ...        ...                                                ...
# 155   156       WFTD  WHITE FOX TRIPLE DISTILLED VODKA NAUGHTY GREEN...
# 156   157        WFV                                    WHITE FOX VODKA
# 157   158        WFV                                    WHITE FOX VODKA
# 158   159        WFV                                    WHITE FOX VODKA
# 159   160        WFV                                    WHITE FOX VODKA
#
#      Size Value (ml)  Pack Size  Retail Price (Rs)  \
# ...

# %%
data3.tail()
# Out:
#      S No Brand Code                                         Brand Name  \
# 155   156       WFTD  WHITE FOX TRIPLE DISTILLED VODKA NAUGHTY GREEN...
# 156   157        WFV                                    WHITE FOX VODKA
# 157   158        WFV                                    WHITE FOX VODKA
# 158   159        WFV                                    WHITE FOX VODKA
# 159   160        WFV                                    WHITE FOX VODKA
#
#      Size Value (ml)  Pack Size  Retail Price (Rs)  \
# 155              750         12                490
# 156               90         96                 55
# 157              180         48                110
# 158              375         24                225
# 159              750         12                450
#
#                        Warehouse Name
# 155  SOM DISTILLERIES & BREWERIES LTD
# 156  SOM DISTILLERIES & BREWERIES LTD
# 157  SOM DISTILLERIES & BREWERIES LTD
# 158  SOM DISTILLERIES & BREWERIES LTD
# ...

# %%
data.head()
# Out:
#    S No Brand Code                         Brand Name  Size Value (ml)  \
# 0     1      BMSEB       BAD MONKEY SUPER STRONG BEER              330
# 1     2      BMSEB       BAD MONKEY SUPER STRONG BEER              500
# 2     3      BMSEB       BAD MONKEY SUPER STRONG BEER              650
# 3     4       BIIS  BECK'S ICE INTERNATIONAL STRENGTH              500
# 4     5       BIIS  BECK'S ICE INTERNATIONAL STRENGTH              650
#
#    Pack Size  Retail Price (Rs)                      Warehouse Name
# 0         24                 70  M/S SINQ BEVERAGES PRIVATE LIMITED
# 1         24                100  M/S SINQ BEVERAGES PRIVATE LIMITED
# 2         12                130  M/S SINQ BEVERAGES PRIVATE LIMITED
# 3         24                105  M/S ANHEUSER BUSCH INBEV INDIA LTD
# 4         12                140  M/S ANHEUSER BUSCH INBEV INDIA LTD

# %%
beer = data.drop(['Brand Code', 'Warehouse Name'], axis=1)

# %%
beer.head()
# Out:
#    S No                         Brand Name  Size Value (ml)  Pack Size  \
# 0     1       BAD MONKEY SUPER STRONG BEER              330         24
# 1     2       BAD MONKEY SUPER STRONG BEER              500         24
# 2     3       BAD MONKEY SUPER STRONG BEER              650         12
# 3     4  BECK'S ICE INTERNATIONAL STRENGTH              500         24
# 4     5  BECK'S ICE INTERNATIONAL STRENGTH              650         12
#
#    Retail Price (Rs)
# 0                 70
# 1                100
# 2                130
# 3                105
# 4                140

# %%
whisky = data1.drop(['Brand Code', 'Warehouse Name'], axis=1)

# %%
whisky.head()
# Out:
#    S No                      Brand Name  Size Value (ml)  Pack Size  \
# 0     1  100 PIPER BLEND.S. WHISKY 12YO               60        150
# 1     2  100 PIPER BLEND.S. WHISKY 12YO              180         48
# 2     3  100 PIPER BLEND.S. WHISKY 12YO              375         24
# 3     4  100 PIPER BLEND.S. WHISKY 12YO              750         12
# 4     5    100 PIPERS DL BLE SC. WHISKY               60        150
#
#    Retail Price (Rs)
# 0                160
# 1                495
# 2               1000
# 3               2000
# 4                115

# %%
d_beer = data2.drop(['Brand Code', 'Warehouse Name'], axis=1)

# %%
d_beer.head()
# Out:
#    S No                                        Brand Name  Size Value (ml)  \
# 0     1     BIRA 91 BLONDE SUMMER LAGER BEER DRAUGHT BEER            20000
# 1     2     BIRA 91 BLONDE SUMMER LAGER BEER DRAUGHT BEER            30000
# 2     3  BIRA 91 INDIAN PALE ALE POMELO BEER DRAUGHT BEER            20000
# 3     4  BIRA 91 INDIAN PALE ALE POMELO BEER DRAUGHT BEER            30000
# 4     5           BIRA 91 MALABAR STOUT BEER DRAUGHT BEER            20000
#
#    Pack Size  Retail Price (Rs)
# 0          1               3410
# 1          1               5115
# 2          1               6835
# 3          1              10255
# 4          1               6835

# %%
vodka= data3.drop(['Brand Code', 'Warehouse Name'], axis=1)

# %%
vodka.head(),vodka.tail()
# Out:
# (   S No                  Brand Name  Size Value (ml)  Pack Size  \
#  0     1                 ARTIC VODKA               60        150
#  1     2                 ARTIC VODKA              180         48
#  2     3                 ARTIC VODKA              750         12
#  3     4  ARTIC VODKA NATURAL ORANGE               60        150
#  4     5  ARTIC VODKA NATURAL ORANGE              180         48
#
#     Retail Price (Rs)
#  0                 70
#  1                210
#  2                840
#  3                 75
#  4                225  ,
#       S No                                         Brand Name  Size Value (ml)  \
#  155   156  WHITE FOX TRIPLE DISTILLED VODKA NAUGHTY GREEN...              750
#  156   157                                    WHITE FOX VODKA               90
#  157   158                                    WHITE FOX VODKA              180
#  158   159                                    WHITE FOX VODKA              375
# ...

# %%
vodka.isnull().sum()
# Out:
# S No                 0
# Brand Name           0
# Size Value (ml)      0
# Pack Size            0
# Retail Price (Rs)    0
# dtype: int64

# %%
whisky.isnull().sum()
# Out:
# S No                 0
# Brand Name           0
# Size Value (ml)      0
# Pack Size            0
# Retail Price (Rs)    0
# dtype: int64

# %%
d_beer.isnull().sum()
# Out:
# S No                 0
# Brand Name           0
# Size Value (ml)      0
# Pack Size            0
# Retail Price (Rs)    0
# dtype: int64

# %%
correlation=beer.corr()

# %%
correlation
# Out:
#                        S No  Size Value (ml)  Pack Size  Retail Price (Rs)
# S No               1.000000         0.069809  -0.016741           0.089896
# Size Value (ml)    0.069809         1.000000  -0.562523           0.988952
# Pack Size         -0.016741        -0.562523   1.000000          -0.473917
# Retail Price (Rs)  0.089896         0.988952  -0.473917           1.000000

# %%
beer.head()['Pack Size'].plot.bar()

# %%
sb.pairplot(beer)

# %%
sb.relplot(x='Size Value (ml)', y='Retail Price (Rs)', data=beer)

# %%
whisky['Retail Price (Rs)'].plot.barh()

# %%
whisky['Size Value (ml)'].plot.barh()

# %%
whisky['Retail Price (Rs)'].plot.line()

# %%
whisky.groupby('Size Value (ml)')['Retail Price (Rs)'].agg(np.max).plot.pie()
